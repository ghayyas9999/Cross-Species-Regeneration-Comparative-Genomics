# %%
import scanpy as sc
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

print("Environment OK")
print("Scanpy:", sc.__version__)
print("Pandas:", pd.__version__)
print("NumPy:", np.__version__)
# Out:
# Environment OK
# Scanpy: 1.11.5
# Pandas: 2.3.3
# NumPy: 2.2.6
# /tmp/ipykernel_5003/3754392525.py:7: FutureWarning: `__version__` is deprecated, use `importlib.metadata.version('scanpy')` instead
#   print("Scanpy:", sc.__version__)
